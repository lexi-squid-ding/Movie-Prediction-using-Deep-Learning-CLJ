# %% [markdown]
# # Download Poster URLs from Top 1000 movies from 2005-2010 (6 years)
#
# - Should get total 6000 posters
# - Also download genre ID

# %%
# code to download all English movies in 2012-2016
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import seaborn as sns # Seaborn visualization package
import pandas as pd
import time
import re # Regex
import collections

# File reading things
import pickle
import json
import csv
import datetime # For handling dates

# The "requests" library makes working with HTTP requests easier
import requests
import os
from bs4 import BeautifulSoup
from IPython.display import Image, display # Display image from URL
from IPython.core.display import HTML # Display image from URL

# TMDB API wrapper
import tmdbsimple as tmdb

# IMDB access
import imdb

# Display options
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
# %matplotlib inline

# %%
release_year_range = range(2005,2011)
release_year_range

# Get 20 results per page, and want 1000 movies => 50 pages to download. 
n_pages_per_year = 1000/20

# %%
### Viewing metadata and downloading poster URLs
# My API key (Lexi)
tmdb.API_KEY = 'ee0df3ce88063f7f6cd466ff61266a55'
    
# Create empty list to store each page: n_pages x n_years
movies_list = [None] * int( n_pages_per_year * len(release_year_range))

# For each year
ind = 0
for i in range(len(release_year_range)):
    release_year = int(release_year_range[i])
    
    # Get first n_pages_per_year pages of movie data
    for page_n in range(1, n_pages_per_year + 1):
        url ='https://api.themoviedb.org/3/discover/movie?api_key=ee0df3ce88063f7f6cd466ff61266a55&language=en-US&sort_by=popularity.desc&include_adult=false&include_video=false&page='+ str(page_n)+ '&primary_release_year=' + str(release_year) + '&with_original_language=en'
        response_page = requests.get(url)
        movies_list[ind] = response_page.json()
        ind = ind + 1
        # pause for a bit
        time.sleep(0.5)

# %%
len(movies_list)
# Out:
# 300

# %%
file_name = 'poster_urls_Top1000_each_2005-2016.csv'

### Save json contents as CSV
# movies_per_page = 20

with open(file_name, "w") as file:
    csv_file = csv.writer(file)  
    # Add column names: poster URL, Title, release date, ID, Genres
    csv_file.writerow(['poster_path', 'release_date', 'id', 'genre_ids'])
    
    # For each page in list, get attributes of movie
    for i in range(len(movies_list)):
        # For each movie in the page
        for item in movies_list[i]['results']:
            csv_file.writerow([item['poster_path'], item['release_date'], item['id'], item['genre_ids']])

# %%
movies_list[i]
# Out:
# {u'page': 50,
#  u'results': [{u'adult': False,
#    u'backdrop_path': u'/enOlEH5j9yu8lfT7DHarU3Xy2hz.jpg',
#    u'genre_ids': [27],
#    u'id': 137618,
#    u'original_language': u'en',
#    u'original_title': u'\u0e43\u0e04\u0e23...\u0e43\u0e19\u0e2b\u0e49\u0e2d\u0e07',
#    u'overview': u'Nida (Sinjai Plengpanich) is a single mother who takes care of her anti-social son who has locked himself in his room for five years. The only way to communicate with her son is to write on a piece of paper and slip it under the door. But, when outsiders start to get curious about what is going on behind the door of her son\u2019s room, a series of terrible events starts to happen.',
#    u'popularity': 1.036701,
#    u'poster_path': u'/nbIKkOlqjoqdqgbB2dRV2pkvXVf.jpg',
#    u'release_date': u'2010-09-03',
#    u'title': u'Who Are You?',
#    u'video': False,
#    u'vote_average': 6.2,
#    u'vote_count': 5},
#   {u'adult': False,
#    u'backdrop_path': u'/zwauZI4GANu0CcfM1HDmJsZUEzg.jpg',
#    u'genre_ids': [18, 10749],
#    u'id': 54469,
#    u'original_language': u'en',
#    u'original_title': u'Main Street',
#    u'overview': u'From the once thriving tobacco warehouses, to the current run-down and closed shops of Five Points, a diverse group of residents and their respective life changes when outsider Gus Leroy brings something new and potentially dangerous into their quiet town.',
#    u'popularity': 1.036342,
#    u'poster_path': u'/zrEecTo4dZsD0lqcsYIx4zFGwOX.jpg',
#    u'release_date': u'2010-10-21',
#    u'title': u'Main Street',
#    u'video': False,
#    u'vote_average': 3.3,
#    u'vote_count': 11},
#   {u'adult': False,
#    u'backdrop_path': u'/72fAR1ird16tmRcvTWW6N3J3nkN.jpg',
#    u'genre_ids': [35],
#    u'id': 43814,
#    u'original_language': u'en',
#    u'original_title': u'Something Like A Business',
#    u'overview': u'An aspiring pimp struggles to make a mint after inheriting his late uncles escort service and discovering that competition on the streets is fierce.',
#    u'popularity': 1.03619,
#    u'poster_path': u'/h6zVzEozN7MDfaGagc54YLiOhlj.jpg',
#    u'release_date': u'2010-06-15',
#    u'title': u'Something Like A Business',
#    u'video': False,
#    u'vote_average': 4,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/kWGQSJK3YV4GOIuelM12jKSujAR.jpg',
#    u'genre_ids': [35],
#    u'id': 61107,
#    u'original_language': u'en',
#    u'original_title': u'The Con Artist',
#    u'overview': u'An ex-con finds his plan to go straight foiled by a loan shark who manipulates his target into taking on one last heist.',
#    u'popularity': 1.035105,
#    u'poster_path': u'/jtw1E1jmf2PvrevX79cRoA0xONf.jpg',
#    u'release_date': u'2010-11-25',
#    u'title': u'The Con Artist',
#    u'video': False,
#    u'vote_average': 4.3,
#    u'vote_count': 8},
#   {u'adult': False,
#    u'backdrop_path': u'/k8XipOEHLgcO8DC7h7LQsAyhH4s.jpg',
#    u'genre_ids': [10402, 99],
#    u'id': 40690,
#    u'original_language': u'en',
#    u'original_title': u'Black Sabbath: Paranoid',
#    u'overview': u'The story of how the classic album "Paranoid" was made, with stories from band members to those who were influenced by its content, form and vitality.  Paranoid is the second studio album by English rock band Black Sabbath. Released in September 1970, it was the band\'s only LP to top the UK Albums Chart until the release of 13 in 2013. Paranoid contains several of the band\'s signature songs, including "Iron Man", "War Pigs" and the title track, which was the band\'s only Top 20 hit, reaching number 4 in the UK charts. It is often regarded as one of the most quintessential and influential albums in heavy metal history.',
#    u'popularity': 1.034923,
#    u'poster_path': u'/e7ybaDPSY5bxyFsLXYxAxegXv0b.jpg',
#    u'release_date': u'2010-06-28',
#    u'title': u'Black Sabbath: Paranoid',
#    u'video': False,
#    u'vote_average': 6.2,
#    u'vote_count': 5},
#   {u'adult': False,
#    u'backdrop_path': None,
#    u'genre_ids': [14],
#    u'id': 191476,
#    u'original_language': u'en',
#    u'original_title': u'42 One Dream Rush',
#    u'overview': u'An omnibus of 42 short films by auteur directors based on Dreams.',
#    u'popularity': 1.034649,
#    u'poster_path': u'/34PeOFQczaCgqu8AwOaBo3GMAyj.jpg',
#    u'release_date': u'2010-09-15',
#    u'title': u'42 One Dream Rush',
#    u'video': False,
#    u'vote_average': 5,
#    u'vote_count': 1},
#   {u'adult': False,
#    u'backdrop_path': u'/dMePIMw1IS7FUt25DT65M7V0mDZ.jpg',
#    u'genre_ids': [10402, 99],
#    u'id': 92672,
#    u'original_language': u'en',
#    u'original_title': u'Rush: Classic Albums: 2112 & Moving Pictures',
#    u'overview': u'2112 was the album that saw Rush break through to major chart success, going to No.1 in their native Canada and Top 75 in the USA where it would eventually be certified triple platinum. Moving Pictures opened them to a mass audience for the first time and remains the biggest selling album of their career. It also went to No.1 in Canada and went quadruple platinum there while hitting No.3 in both the UK and USA. Rush members Geddy Lee, Alex Lifeson and Neil Peart talk us through the making of the albums, together with original producer Terry Brown via interviews, demonstrations, archive videos and use of the original multi-track tapes.',
#    u'popularity': 1.034547,
#    u'poster_path': u'/52VcBHPuQZLw3m0NsqDNjfyqTv2.jpg',
#    u'release_date': u'2010-09-28',
#    u'title': u'Rush: Classic Albums: 2112 & Moving Pictures',
#    u'video': False,
#    u'vote_average': 5.3,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/9NJjWtiP0B1sAFtvZ7EPzg2haoz.jpg',
#    u'genre_ids': [18, 10769, 10749],
#    u'id': 50493,
#    u'original_language': u'en',
#    u'original_title': u'Brilliantlove',
#    u'overview': u'A photographer and a taxidermist have a summer relationship.',
#    u'popularity': 1.03407,
#    u'poster_path': u'/dL0yvnmxFIscIzGUXjlzP55dOQG.jpg',
#    u'release_date': u'2010-04-23',
#    u'title': u'Brilliantlove',
#    u'video': False,
#    u'vote_average': 2.3,
#    u'vote_count': 4},
#   {u'adult': False,
#    u'backdrop_path': u'/m9CjswSuKNzGihDRomXF0Fnah2I.jpg',
#    u'genre_ids': [35, 10769],
#    u'id': 43019,
#    u'original_language': u'en',
#    u'original_title': u"Schuks Tshabalala's Survival Guide to South Africa",
#    u'overview': u'Leon Schuster or \u201cSchuks Tshabalala\u201d and Shorty (Alfred Ntombela) intend to produce a movie as a visual guide and aid for foreigners coming to SA for the World Cup. Schuks Tshabalala is a teacher and tour guide to a mixed bag of tourists who are taking his survival guide to SA very seriously. Shorty, as usual, is his best friend, assistant and conscience. The students include \u201dHeinz\u201d from Germany, \u201cYoti\u201d from Greece, \u201cJean-Pierre\u201d from France, \u201cKoert\u201d from The Netherlands, \u201cRajin\u201d from India, \u201cMaggie\u201d from Ireland and \u201cXing Xang\u201d from China, among others. They are genuinely eager to learn about SA, so Schuks and Shorty are only too happy to oblige. What follows is a series of hysterical demonstrations of life in SA as they attempt to answer all the questions posed by potential visitors.',
#    u'popularity': 1.034007,
#    u'poster_path': u'/sWlsMFATpUH5BQX3y75XA0RNs7J.jpg',
#    u'release_date': u'2010-05-28',
#    u'title': u"Schuks Tshabalala's Survival Guide to South Africa",
#    u'video': False,
#    u'vote_average': 4,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/cwlrq98i5X6btvRSzUDEzydABYD.jpg',
#    u'genre_ids': [35, 18, 10749],
#    u'id': 82622,
#    u'original_language': u'en',
#    u'original_title': u'Violet Tendencies',
#    u'overview': u'A woman tries to distance herself from her gay friends in an effort to land a straight boyfriend.',
#    u'popularity': 1.033588,
#    u'poster_path': u'/wso7suKzmowA9H4PG87aBKbqLep.jpg',
#    u'release_date': u'2010-04-24',
#    u'title': u'Violet Tendencies',
#    u'video': False,
#    u'vote_average': 4.3,
#    u'vote_count': 6},
#   {u'adult': False,
#    u'backdrop_path': u'/9rfI5ExBcyLihMWpn21w3bsagWh.jpg',
#    u'genre_ids': [80, 18],
#    u'id': 58026,
#    u'original_language': u'en',
#    u'original_title': u'Rosario',
#    u'overview': u"Based on a true story and set in one of the most colorful periods in Philippine history, ROSARIO is destined to be a modern masterpiece in Philippine filmmaking. It is a monumental yet intimate portrait of a woman's emancipation and the sometimes painful consequencesof following one's desires.",
#    u'popularity': 1.033488,
#    u'poster_path': u'/eomac5Gd3MZzBIGtgE9fVBEAB18.jpg',
#    u'release_date': u'2010-12-02',
#    u'title': u'Rosario',
#    u'video': False,
#    u'vote_average': 0,
#    u'vote_count': 0},
#   {u'adult': False,
#    u'backdrop_path': u'/aUgDtN0u5RBrpStDoFV2rYwRjsl.jpg',
#    u'genre_ids': [35, 10769],
#    u'id': 69406,
#    u'original_language': u'en',
#    u'original_title': u'Rio Sex Comedy',
#    u'overview': u'Is this possible to reconcile individual happiness and social justice? It is the paradoxical search several foreigners installed in Brazil. Charlotte Rampling incarnates a British esthetic surgeon given to dissuade whoever would like to pass under the lancet. Ir\xe8ne Jacob is an anthropologist Frenchwoman whose of libido concerns override its political conscience. Bill Pullman camps a disturbed American ambassador who flees his most dangerous responsibilities while hiding in one for the favelas for Rio. There, it becomes accessory to the schemes of Fisher Stevens, a tourist guide, doubled of a romantic swindler. All these stories meet in a whimsical comedy nevertheless anchored in the reality of Rio de Janeiro, known rightly like \u201cthe town of wonders.\u201d',
#    u'popularity': 1.033463,
#    u'poster_path': u'/skMtsUTxk6W0clYKd4rYiZk1tLd.jpg',
#    u'release_date': u'2010-09-16',
#    u'title': u'Rio Sex Comedy',
#    u'video': False,
#    u'vote_average': 3.3,
#    u'vote_count': 6},
#   {u'adult': False,
#    u'backdrop_path': None,
#    u'genre_ids': [53, 28, 18],
#    u'id': 282690,
#    u'original_language': u'en',
#    u'original_title': u'Mr. J',
#    u'overview': u'Originally created as a 4 part web series, Mr. J (2010) picks up directly where The Dark Knight (2008) left off, with the Joker imprisoned at Arkham Asylum. He has been put into the care of the ambitious Dr. Harleen Quinzel who thinks she can actually reach the Joker. But over a month long series of interviews which slowly become a courtship, the Joker gradually molds Dr. Quinzel in his image. Now, with Harley Quinn, as she calls herself, wrapped around his finger, the Joker and his new love interest return to Gotham to wreak havoc on the city.',
#    u'popularity': 1.03329,
#    u'poster_path': u'/6b1F0PNtCQb9VO3a3Md1mnarafs.jpg',
#    u'release_date': u'2010-10-18',
#    u'title': u'Mr. J',
#    u'video': False,
#    u'vote_average': 6.8,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/sMnAqxWDeAk4YuyfJQbPA2sinCa.jpg',
#    u'genre_ids': [10751],
#    u'id': 69961,
#    u'original_language': u'en',
#    u'original_title': u'Horse Crazy 2: The Legend of Grizzly Mountain',
#    u'overview': u'From the makers of "Racing Ace" comes another exciting adventure for the entire family. Grizzly Mountain Ranch is under siege! The bank is trying to take over the land and the Stanger family is bound and determined they are going to hang on to the property that has been in the family for years. In the meantime, notorious horse thieves Luke and Carl Dawson have their sights set on stealing a valuable newborn colt...but for these two bandits a simple crime quickly turns into a comedy of errors when they come up against eight year-old twins BJ and Belle, their teenage babysitter Sam, and a giant grizzly bear named Thor.',
#    u'popularity': 1.033276,
#    u'poster_path': u'/kCIwFgtFw5wlwA97vSr5Q8gDAOa.jpg',
#    u'release_date': u'2010-01-02',
#    u'title': u'Horse Crazy 2: The Legend of Grizzly Mountain',
#    u'video': False,
#    u'vote_average': 5.2,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/g3JSnszjXK2nj1eZU4l6So9AuI3.jpg',
#    u'genre_ids': [35],
#    u'id': 102743,
#    u'original_language': u'en',
#    u'original_title': u'Gabi on the Roof in July',
#    u'overview': u'An ambitious painter on the verge of a big break confronts his moral decay when his idealist, hell-raising, younger sister comes to stay with him in New York City for the summer.',
#    u'popularity': 1.033237,
#    u'poster_path': u'/xUSoahS94W0WR39pZsmVsU1BufU.jpg',
#    u'release_date': u'2010-02-27',
#    u'title': u'Gabi on the Roof in July',
#    u'video': False,
#    u'vote_average': 4.8,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/r3qtzg862fOkt3D8hyLVc6la93z.jpg',
#    u'genre_ids': [],
#    u'id': 213105,
#    u'original_language': u'en',
#    u'original_title': u'Darkness on the Edge of Town: Paramount Theatre, Asbury Park 2009',
#    u'overview': u'An intimate and complete album performance of "Darkness on the Edge of Town" at Paramount Theatre in Asbury Park, New Jersey, shot in 2009. Never-before seen archival footage from the Thrill Hill Vault including complete song performances taken from private band rehearsals, studio sessions, and live concerts during the \u201cDarkness\u201d era.',
#    u'popularity': 1.032918,
#    u'poster_path': u'/2ANkt71nfoQ7QRzoPmuVnu2lgk3.jpg',
#    u'release_date': u'2010-11-16',
#    u'title': u'Darkness on the Edge of Town: Paramount Theatre, Asbury Park 2009',
#    u'video': False,
#    u'vote_average': 0,
#    u'vote_count': 0},
#   {u'adult': False,
#    u'backdrop_path': u'/dn9J7svHFii5k42AMVYTN00WoRU.jpg',
#    u'genre_ids': [99, 10769],
#    u'id': 45374,
#    u'original_language': u'en',
#    u'original_title': u'One Night in Turin',
#    u'overview': u"Before the Premier League and multi-million pound salaries, in England 'football' was a dirty word. The game was in disgrace, the fans, hooligans, the nation, it seemed, were all played out. Then there was Italia '90 - The World Cup - a shot at redemption. But this was no ordinary World Cup and no ordinary time. The manager, Sir Bobby Robson, was under intense media scrutiny, and his team described as 'donkeys'. Yet over six short weeks, through their heroic exploits they united a nation, coming within a heart beat of reaching the World Cup Final. Narrated by Gary Oldman, featuring match action - from Platt's last-gasp winner against Belgium to the silky skills of Gazza and the cool finishing of Linekar - and previously unseen footage, this is the definitive story of England's greatest footballing adventure on foreign soil....so far.",
#    u'popularity': 1.032815,
#    u'poster_path': u'/2AUDvl44XhqSrXROjN2twXhzD9x.jpg',
#    u'release_date': u'2010-05-11',
#    u'title': u'One Night in Turin',
#    u'video': False,
#    u'vote_average': 5.3,
#    u'vote_count': 5},
#   {u'adult': False,
#    u'backdrop_path': None,
#    u'genre_ids': [18],
#    u'id': 51597,
#    u'original_language': u'en',
#    u'original_title': u'Chasing 3000',
#    u'overview': u'As the 1972 baseball season draws to a close and star player Roberto Clemente prepares to knock hit number 3,000 out of the park, two brothers -- one of whom is afflicted with muscular dystrophy -- make the drive from Los Angeles to Pittsburgh in hopes of witnessing sports history in the making. Based on a true story, Chasing 3000 is directed by Gregory J. Lanesey and features Ray Liotta.',
#    u'popularity': 1.032669,
#    u'poster_path': u'/koA9VgXTKl7NqnybxYjyy3AODtL.jpg',
#    u'release_date': u'2010-07-15',
#    u'title': u'Chasing 3000',
#    u'video': False,
#    u'vote_average': 5.3,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/sRBhdAdMJd3oHjtBkeRrzABx3JF.jpg',
#    u'genre_ids': [35, 27],
#    u'id': 28596,
#    u'original_language': u'en',
#    u'original_title': u'Silent But Deadly',
#    u'overview': u'Thomas Capper is an unconventional and mysterious serial killer who takes aim at a Hollywood film set, by unleashing his own brand of retribution on the cast and crew.',
#    u'popularity': 1.032554,
#    u'poster_path': u'/fMKkLEp278E8qx1W5gN8XLjZp3I.jpg',
#    u'release_date': u'2010-01-01',
#    u'title': u'Silent But Deadly',
#    u'video': False,
#    u'vote_average': 4.3,
#    u'vote_count': 3},
#   {u'adult': False,
#    u'backdrop_path': u'/kBLi4wC0qlrgaoEG0RVd3JLQHx8.jpg',
#    u'genre_ids': [18],
#    u'id': 148800,
#    u'original_language': u'en',
#    u'original_title': u'Triple Standard',
#    u'overview': u'A homophobic ex basketball star is forced to face the reality that he himself is gay.',
#    u'popularity': 1.032421,
#    u'poster_path': u'/cAp7kWDqAGB3UePxEo2HFh4vsXf.jpg',
#    u'release_date': u'2010-08-13',
#    u'title': u'Triple Standard',
#    u'video': False,
#    u'vote_average': 5.2,
#    u'vote_count': 3}],
#  u'total_pages': 304,
#  u'total_results': 6066}

# %%
# Check if CSV is readable- print head + tail

Posters_df = pd.read_csv(file_name)
print Posters_df.shape
print Posters_df.head(n=3)
print Posters_df.tail(n=3)
# Out:
# (6000, 4)
#                         poster_path release_date   id        genre_ids
# 0  /6sASqcdrEHXxUhA3nFpjrRecPD2.jpg   2005-11-05  674  [12, 14, 10751]
# 1  /dr6x4GyyegBWtinPBzipY02J2lV.jpg   2005-06-14  272     [28, 80, 18]
# 2  /AoGpqw4S4ZGgwhlM3FgzFVwyIGl.jpg   2005-12-11  752     [28, 53, 14]
#                            poster_path release_date      id genre_ids
# 5997  /koA9VgXTKl7NqnybxYjyy3AODtL.jpg   2010-07-15   51597      [18]
# 5998  /fMKkLEp278E8qx1W5gN8XLjZp3I.jpg   2010-01-01   28596  [35, 27]
# 5999  /cAp7kWDqAGB3UePxEo2HFh4vsXf.jpg   2010-08-13  148800      [18]

# %%
# Check n missing poster path
print 'N posters missing URL:',np.sum(Posters_df['poster_path'].isnull())
# Out:
# N posters missing URL: 37
